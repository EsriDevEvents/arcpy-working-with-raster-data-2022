# %% [markdown]
# ## Demo 2: Raster Analysis

# %% [markdown]
# ### Learning objectives
#
# 1. Use basic algebraic expressions to create new raster data
# 2. Use ArcGIS tools, functions and create complex parameters
# 3. Apply environment settings and use complex expressions to streamline a workflow

# %% [markdown]
# ### Example problem: A suitability model for Bobcat habitat
#
# _**What is a suitability model?**_
#
# A suitability model identifies the best locations to site things such as a new shopping center, a housing development, or a ski area or it identifies the best areas to set aside for things such as parks, bobcat habitat, or for flood control.
#
#
# _**Bobcat habitat example**_
#
# In our simple bobcat example, our goal is to identify the best areas to set aside for bobcat habitat and we will have three criteria:
#
# 1. Slope – they prefer steeper over flatter slopes for safety
# 2. Land use types – they prefer certain land use types (such as deciduous and conifer forests) more than others (such as commercial and residential)
# 3. Distance to streams – locations closer to streams are more preferred

# %% [markdown]
# ![suitability_workflow](suitability_workflow.png)

# %%
import arcpy
from arcpy.sa import *
arcpy.env.workspace = r'C:\DevSummit\PythonRaster\Data\Demo2\Data.gdb'

# %% [markdown]
# The `arcpy.env.addOutputsToMap` allows you to control whether intermediate outputs you create during your explanatory analysis will be added to the map. Set it back to `True` to add the output to the map.

# %% [markdown]
# ### Create the slope criterion

# %% [markdown]
# #### Derive Slope from elevation applying Spatial Analyst tools and simple expressions

# %%
## Read the elevation raster created in Demo 1

elev = Raster(r'Elevation_sa')

# %%
elev_m = elev * 0.3048
slope = SurfaceParameters(elev_m, "SLOPE", "", "", "", "", "")

# %%
slope = SurfaceParameters(elev*0.3048, "SLOPE", "", "", "", "", "")  # alternative way to chain operations together

# %%
slope
# Out:
# C:\DevSummit\PythonRaster\Demo.gdb\Surface_x62d1

# %% [markdown]
# #### Transform the slope criterion to scores that reflect preference for habitat areas

# %% [markdown]
# We will remap slope degrees to the following suitability scores. Note that the scores have been remapped from 1 to 10 which is the same range that will be used for other criteria.
#
# | Start | End | Suitability Score |
# |-------|-----|-----|
# | 0     | 3   | 1   |
# | 3     | 10  | 3   |
# | 10    | 25  | 6   |
# | 25    | 90  | 10  |

# %% [markdown]
# `RemapRange` is an object useful to pass to the `Reclassify` tool the new values to which a range will be mapped.

# %% [markdown]
# Why am I using RemapRange, why specific this complex parameter, justify why this and others than can be used

# %%
remap_table = RemapRange([[0,3,1], [3,10,3], [10,25,6], [25,90,10]])

# %%
slope_transformed = Reclassify(slope, "Value", remap_table) # Using the remap_table object that was created above

# %%
slope_transformed
# Out:
# C:\DevSummit\PythonRaster\Demo.gdb\Reclass_Surf1

# %% [markdown]
# ### Create the landuse criterion

# %%
landuse = Raster('Landuse_sa')

# %%
landuse
# Out:
# Landuse_sa

# %% [markdown]
# #### Remap landuse to suitability scores:
#
# | Landuse                            | Old Value | New Value |
# |------------------------------------|-----------|-----------|
# | Agriculture                        | 4         | 2         |
# | Bare Land                          | 11        | 10        |
# | Developed, High Intensity          | 1         | 1         |
# | Developed, Low Intensity           | 3         | 1         |
# | Developed, Medium Intensity        | 2         | 1         |
# | Forest, Coniferous                 | 7         | 10        |
# | Forest, Deciduous                  | 6         | 10        |
# | Forest, Mixed Deciduous-Coniferous | 8         | 10        |
# | Grassland                          | 5         | 8         |
# | Scrub/Shrub                        | 9         | 6         |
# | Water                              | 12        | 1         |
# | Wetland                            | 10        | 2         |

# %%
remap_table = RemapValue([[4,2], [11,10], [1,1], [3,1], [2,1], [7,10], 
                          [6,10] ,[8,10], [5,8], [9,6], [12,1], [10,2]])

# %%
landuse_transformed = Reclassify(landuse, "Value", remap_table)

# %% [markdown]
# ### Create the distance to streams criterion

# %%
arcpy.Clip_analysis("Streams", "StudyArea", "C:\DevSummit\PythonRaster\Data\Demo2\streams_clip")
# Out:
# <Result 'C:\\DevSummit\\PythonRaster\\Data\\Demo2\\streams_clip.shp'>

# %%
dist_to_streams = DistanceAccumulation("C:\DevSummit\PythonRaster\Data\Demo2\streams_clip")

# %% [markdown]
# #### Alternative way that combines non-raster analysis tool with raster analysis tool in one single expression

# %% [markdown]
# managed temporary feature data output and deleated afterwards

# %%
dist_to_streams = DistanceAccumulation(arcpy.Clip_analysis("Streams", "StudyArea", "#"))

# %% [markdown]
# Previous criteria have been remapped using the `Reclassify` tool, for Distance to Streams, we will use a function to remap the values to a continuous range between 1 and 10.
# To learn more about the different functions available, see [Rescale by Function (Spatial Analyst)](https://pro.arcgis.com/en/pro-app/latest/tool-reference/spatial-analyst/rescale-by-function.htm).

# %%
dist_to_streams_transformed = RescaleByFunction(dist_to_streams, TfMSSmall(), 1, 10)

# %% [markdown]
# ### Weight criteria relative to one another and combine

# %%
suitability_map = slope_transformed * 0.2 + \
                  landuse_transformed * 0.5 + \
                  dist_to_streams_transformed * 0.3

# %%
suitability_map
# Out:
# C:\Users\tan11562\AppData\Local\Temp\1\ArcGISProTemp33932\x09e19706_bdfa_4326_ba09_7167eecdc85ay0.afr

# %%
Render(suitability_map, colormap="Red-Yellow-Green (Continuous)")
# Out:
# C:\Users\tan11562\AppData\Local\Temp\1\ArcGISProTemp33932\xa80ac755_e2f1_4ca6_a9f8_8136f2ebd83ey0.afr

# %% [markdown]
# ### Analysis environment

# %%
arcpy.env.cellSize = 100

# %%
arcpy.env.outputCoordinateSystem = arcpy.SpatialReference(3857)  # Web_Mercator_Auxiliary_Sphere

# %% [markdown]
# ### Combining each individual statement into one complex expression

# %% [markdown]
# Running each statement individually is an appropriate approach during exploratory analysis. When the analysis steps are already determined, it is possible to combine all individual statements into a single complex expression that returns the final output of interest.

# %%
suitability_map = Reclassify(SurfaceParameters(elev * 0.3048), 
                             "Value", 
                             RemapRange([[0,3,1], [3,10,3], [10,25,6], [25,90,10]])) * 0.2 


#                   Reclassify(landuse, 
#                              "Value", 
#                              RemapValue([[4,2], [11,10], [1,1], [3,1], [2,1], [7,10], 
#                                          [6,10] ,[8,10], [5,8], [9,6], [12,1], [10,2]])) * 0.5 + \
#                   RescaleByFunction(DistanceAccumulation(arcpy.Clip_analysis("Streams", 
#                                                                              "StudyArea", 
#                                                                              "#")), 
#                                    TfMSSmall(), 1, 10) * 0.3

# %%
print('Output cell size is {} x {}'.format(suitability_map.meanCellHeight, 
                                           suitability_map.meanCellWidth))
# Out:
# Output cell size is 100.0 x 100.0

# %%
print("Output map project is {}".format(suitability_map.spatialReference.PCSName))
# Out:
# Output map project is WGS_1984_Web_Mercator_Auxiliary_Sphere
